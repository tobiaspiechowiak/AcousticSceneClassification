150
# 768/768 [==============================] - 0s 113us/step - loss: 0.5844 - acc: 0.7122
# Epoch 130/150
# 768/768 [==============================] - 0s 86us/step - loss: 0.5823 - acc: 0.7148
# Epoch 131/150
# 768/768 [==============================] - 0s 88us/step - loss: 0.5866 - acc: 0.7109
# Epoch 132/150
# 768/768 [==============================] - 0s 64us/step - loss: 0.5849 - acc: 0.7148
# Epoch 133/150
# 768/768 [==============================] - 0s 91us/step - loss: 0.5840 - acc: 0.7070
# Epoch 134/150
# 768/768 [==============================] - 0s 105us/step - loss: 0.5861 - acc: 0.7109
# Epoch 135/150
# 768/768 [==============================] - 0s 62us/step - loss: 0.5850 - acc: 0.7161
# Epoch 136/150
# 768/768 [==============================] - 0s 64us/step - loss: 0.5795 - acc: 0.7227
# Epoch 137/150
# 768/768 [==============================] - 0s 81us/step - loss: 0.5831 - acc: 0.7148
# Epoch 138/150
# 768/768 [==============================] - 0s 84us/step - loss: 0.5839 - acc: 0.7005
# Epoch 139/150
# 768/768 [==============================] - 0s 82us/step - loss: 0.5803 - acc: 0.7214
# Epoch 140/150
# 768/768 [==============================] - 0s 92us/step - loss: 0.5798 - acc: 0.7253
# Epoch 141/150
# 768/768 [==============================] - 0s 130us/step - loss: 0.5836 - acc: 0.7109
# Epoch 142/150
# 768/768 [==============================] - 0s 108us/step - loss: 0.5837 - acc: 0.7083
# Epoch 143/150
# 768/768 [==============================] - 0s 96us/step - loss: 0.5830 - acc: 0.7187
# Epoch 144/150
# 768/768 [==============================] - 0s 118us/step - loss: 0.5849 - acc: 0.7148
# Epoch 145/150
# 768/768 [==============================] - 0s 128us/step - loss: 0.5830 - acc: 0.7109
# Epoch 146/150
# 768/768 [==============================] - 0s 166us/step - loss: 0.5876 - acc: 0.7188
# Epoch 147/150
# 768/768 [==============================] - 0s 111us/step - loss: 0.5895 - acc: 0.7096
# Epoch 148/150
# 768/768 [==============================] - 0s 108us/step - loss: 0.5825 - acc: 0.7148
# Epoch 149/150
# 768/768 [==============================] - 0s 100us/step - loss: 0.5807 - acc: 0.7122
# Epoch 150/150
# 768/768 [==============================] - 0s 95us/step - loss: 0.5800 - acc: 0.7148
# 768/768 [==============================] - 0s 77us/step
#
# acc: 72.53%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-25646f85e20f> in <module>()
#      16 from ann_visualizer.visualize import ann_viz
#      17
# ---> 18 ann_viz(model, title="My first neural network",show=True)
#
# TypeError: ann_viz() got an unexpected keyword argument 'show'

# %%
from ann_visualizer.visualize import ann_viz

ann_viz(model, title="My first neural network")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\program files\python\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     110     try:
# --> 111         proc = subprocess.Popen(cmd, **kwargs)
#     112     except OSError as e:
#
# c:\program files\python\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# c:\program files\python\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#     996                                          os.fspath(cwd) if cwd is not None else None,
# --> 997                                          startupinfo)
#     998             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-22-ff0db9238339> in <module>()
#       1 from ann_visualizer.visualize import ann_viz
#       2
# ----> 3 ann_viz(model, title="My first neural network")
#
# c:\program files\python\lib\site-packages\ann_visualizer\visualize.py in ann_viz(model, view, filename, title)
#     204         g.edge_attr.update(arrowhead="none", color="#707070");
#     205         if view == True:
# --> 206             g.view();
#
# c:\program files\python\lib\site-packages\graphviz\files.py in view(self, filename, directory, cleanup)
#     201         """
#     202         return self.render(filename=filename, directory=directory, view=True,
# --> 203                            cleanup=cleanup)
#     204
#     205     def _view(self, filepath, format):
#
# c:\program files\python\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup)
#     174         filepath = self.save(filename, directory)
#     175
# --> 176         rendered = backend.render(self._engine, self._format, filepath)
#     177
#     178         if cleanup:
#
# c:\program files\python\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     140     """
#     141     cmd, rendered = command(engine, format, filepath)
# --> 142     run(cmd, capture_output=True, check=True, quiet=quiet)
#     143     return rendered
#     144
#
# c:\program files\python\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     112     except OSError as e:
#     113         if e.errno == errno.ENOENT:
# --> 114             raise ExecutableNotFound(cmd)
#     115         else:  # pragma: no cover
#     116             raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tpdf', '-O', 'network.gv'], make sure the Graphviz executables are on your systems' PATH

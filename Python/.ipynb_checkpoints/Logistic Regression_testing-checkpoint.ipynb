# %%
#import packages
import pickle
import pandas as pd

# %%
model = pickle.load(open('LogReg.sav','rb'))

# %%
model
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000.0, multi_class='ovr',
#           n_jobs=1, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=1, warm_start=False)

# %%
model.coef_.size
# Out:
# 860

# %%
#load test vector from training set
path = '../../Recordings/Processed/'
train_test = pd.read_csv(path + 'TrainingSet.csv')

# %%
sample_input = train_test.values[160000:160100,0:215] #samples
sample_class = train_test.values[160000:160100,216] #samples

# %%
voice_input
# Out:
# array([[-1.3231e-03,  1.6759e-03, -1.7119e-03, ...,  7.0303e-06,
#         -2.4076e-05, -4.8124e-05],
#        [-9.5645e-04,  1.7883e-03, -1.5780e-03, ..., -2.2477e-05,
#          4.1661e-05,  7.5803e-05],
#        [-9.3472e-04,  9.6732e-04, -2.4281e-03, ..., -7.2007e-06,
#          1.2065e-05,  4.8847e-05],
#        ...,
#        [ 1.0278e-03, -2.3687e-03, -1.9974e-03, ..., -1.1272e-05,
#          1.5825e-05, -3.4767e-06],
#        [ 8.2508e-04, -2.4369e-03,  2.4848e-03, ..., -1.6254e-06,
#          1.6616e-05,  7.1717e-07],
#        [ 6.6951e-04, -1.8735e-03,  6.1933e-03, ...,  1.9969e-05,
#         -3.4282e-05, -3.1045e-06]])

# %%
voice_class
# Out:
# array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.])

# %%
model.predict(voice_input)
# Out:
# array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.])

# %%
model.predict_proba(voice_input)
# Out:
# array([[0.21257008, 0.40392305, 0.22825397, 0.15525289],
#        [0.21839234, 0.38266208, 0.23836817, 0.16057741],
#        [0.22024395, 0.37546031, 0.24174886, 0.16254688],
#        [0.21992968, 0.37639469, 0.24108827, 0.16258736],
#        [0.22388534, 0.36167363, 0.24806507, 0.16637595],
#        [0.22983271, 0.33916117, 0.25889618, 0.17210993],
#        [0.23217123, 0.32950694, 0.26359998, 0.17472184],
#        [0.23223081, 0.32869453, 0.26397617, 0.17509849],
#        [0.23357413, 0.32314781, 0.26681862, 0.17645943],
#        [0.23716605, 0.3096968 , 0.273333  , 0.17980414],
#        [0.23983119, 0.29942991, 0.27840321, 0.18233569],
#        [0.24007548, 0.29860464, 0.27880267, 0.18251721],
#        [0.23806638, 0.30582296, 0.27547093, 0.18063974],
#        [0.23849662, 0.30413865, 0.27634872, 0.18101601],
#        [0.23888805, 0.30245515, 0.27731386, 0.18134293],
#        [0.23523445, 0.31670358, 0.27023559, 0.17782639],
# ...
